# %%
df = spark.sql("select * from samples.wanderbricks.employees") 
if df.count()!=0 : 
    df.write.partitionBy('country').mode("overwrite").saveAsTable("default.employees_info")
else:
    print("No data in the table")

# %%
from pyspark.sql.functions import * 
from pyspark.sql.window import Window 
# employee_info =  spark.sql("DESCRIBE DETAIL default.employees_info")
employee_info_slct = spark.sql("select * from default.employees_info")
employee_info_slct.select('role').distinct().display() 
employee_info_slct.filter(col('country') == 'China').distinct().display()

# %%
print("abc")
